# %% [markdown]
# # Project: Analyzing Macbeth
#
# ## Introduction
# For our first day and first data science project, we're going to do some rudimentry analysis of Shakespeare's classic play: Macbeth! You will get practice working with lists, condtionals and dictionaries, visualizing data, and thinking analytically about data.
#
# ## Objectives
# You will be able to:
# * Show mastery of the content covered in this section
#
# ## Getting the Data
# Here we start by importing a python package and using it to pull the transcript of Macbeth from the project Gutenberg website. We also preview a few details about what is now stored in the variable macbeth; it's a string with 119,846 characters, the first 500 of which are printed below.

# %%
import matplotlib.pyplot as plt

# %%
import requests
macbeth = requests.get('http://www.gutenberg.org/cache/epub/2264/pg2264.txt').text

print(type(macbeth))
print(len(macbeth))
print(macbeth[:500])
# Out:
# <class 'str'>
# 120253
# ﻿
#
# ***The Project Gutenberg's Etext of Shakespeare's First Folio***
# ********************The Tragedie of Macbeth*********************
#
#
#
# *******************************************************************
# THIS EBOOK WAS ONE OF PROJECT GUTENBERG'S EARLY FILES PRODUCED AT A
# TIME WHEN PROOFING METHODS AND TOOLS WERE NOT WELL DEVELOPED. THERE
# IS AN IMPROVED EDITION OF THIS TITLE WHICH MAY BE VIEWED AS EBOOK
# (#1533) at https://www.gutenberg.org/ebooks/1533
# *********************************

# %% [markdown]
# ## Your Task
#
# Your task is to create a bar graph of the 25 most common words in Shakespeare's Macbeth.
#
#
# A common python programming pattern to counting objects, produce histograms, or update statistics is to make calls to a dictionary as you iterate through a list. For example, given a list of words, you can create a dictionary to store counts and then iterate through the list of words, checking how many times each word has appeared using your dictionary, and updating the dictionary count now that you've seen that word again. The `dictionary.get()` method is very useful in doing this. Read the docstring for the dictionary.get() method and use it along with the pseudocode above to create a bar graph of the 25 most common words from the transcript of Macbeth which has been loaded into a variable 'Macbeth'. Be sure to include a title and appropriate labels for your graph.

# %%
# Split the transcript into words
words = macbeth.lower().split(" ")
words[:10]
# Out:
# ['\ufeff\r\n\r\n***the',
#  'project',
#  "gutenberg's",
#  'etext',
#  'of',
#  "shakespeare's",
#  'first',
#  'folio***\r\n********************the',
#  'tragedie',
#  'of']

# %%
word_count_dictionary = {}

for word in words:
    if word in word_count_dictionary.keys():
        word_count_dictionary[word] += 1
    else:
        word_count_dictionary[word] = 1
print(word_count_dictionary)
# Out:
# {'\ufeff\r\n\r\n***the': 1, 'project': 25, "gutenberg's": 4, 'etext': 20, 'of': 397, "shakespeare's": 6, 'first': 18, 'folio***\r\n********************the': 2, 'tragedie': 6, 'macbeth*********************\r\n\r\n\r\n\r\n*******************************************************************\r\nthis': 1, 'ebook': 1, 'was': 39, 'one': 29, 'early': 1, 'files': 1, 'produced': 1, 'at': 50, 'a\r\ntime': 2, 'when': 28, 'proofing': 2, 'methods': 1, 'and': 426, 'tools': 1, 'were': 34, 'not': 145, 'well': 11, 'developed.': 1, 'there\r\nis': 1, 'an': 28, 'improved': 1, 'edition': 3, 'this': 117, 'title': 2, 'which': 45, 'may': 40, 'be': 137, 'viewed': 1, 'as': 71, 'ebook\r\n(#1533)': 1, 'https://www.gutenberg.org/ebooks/1533\r\n*******************************************************************\r\n\r\n\r\n\r\nthis': 1, 'is': 187, 'our': 118, '3rd': 1, 'most': 26, 'these': 31, 'plays.': 1, '': 1327, 'see': 29, 'the': 639, 'index.\r\n\r\n\r\ncopyright': 1, 'laws': 2, 'are': 66, 'changing': 1, 'all': 67, 'over': 2, 'world,': 1, 'sure': 3, 'to': 373, 'check\r\nthe': 1, 'copyright': 5, 'for': 104, 'your': 127, 'country': 3, 'before': 14, 'posting': 1, 'files!!\r\n\r\nplease': 1, 'take': 19, 'a': 254, 'look': 2, 'important': 1, 'information': 4, 'in': 185, 'header.\r\nwe': 1, 'encourage': 1, 'you': 200, 'keep': 2, 'file': 4, 'on': 55, 'own': 1, 'disk,': 1, 'keeping': 1, 'an\r\nelectronic': 1, 'path': 1, 'open': 1, 'next': 3, 'readers.': 2, 'do': 37, 'remove': 1, 'this.\r\n\r\n\r\n**welcome': 1, 'world': 3, 'free': 5, 'plain': 3, 'vanilla': 1, 'electronic': 1, 'texts**\r\n\r\n**etexts': 1, 'readable': 1, 'by': 54, 'both': 10, 'humans': 1, 'computers,': 1, 'since': 6, '1971**\r\n\r\n*these': 1, 'etexts': 8, 'prepared': 3, 'hundreds': 1, 'volunteers': 1, 'donations*\r\n\r\ninformation': 1, 'contacting': 1, 'gutenberg': 12, 'get': 15, 'etexts,': 5, 'and\r\nfurther': 1, 'included': 1, 'below.': 1, 'we': 79, 'need': 6, 'donations.\r\n\r\n\r\nthe': 1, 'macbeth\r\n\r\nby': 1, 'william': 1, 'shakespeare\r\n\r\njuly,': 1, '2000': 1, '[etext': 1, '#2264]\r\n\r\n\r\n***the': 1, 'macbeth*********************\r\n\r\n*****this': 1, 'should': 42, 'named': 1, '2264.txt': 1, 'or': 62, '2264.zip******\r\n\r\nproject': 1, 'usually': 2, 'created': 1, 'from': 58, 'multiple': 1, 'editions,\r\nall': 1, 'public': 5, 'domain': 4, 'united': 3, 'states,': 1, 'unless': 2, 'a\r\ncopyright': 1, 'notice': 2, 'included.': 1, 'therefore,': 1, 'any\r\nof': 1, 'books': 2, 'compliance': 1, 'with': 140, 'any': 21, 'particular': 1, 'paper': 1, 'edition.\r\n\r\n\r\nwe': 1, 'now': 25, 'trying': 1, 'release': 4, 'month': 2, 'advance\r\nof': 1, 'official': 2, 'dates,': 1, 'leaving': 1, 'time': 16, 'better': 9, 'editing.\r\n\r\nplease': 1, 'note:': 1, 'neither': 2, 'list': 2, 'nor': 23, 'its': 3, 'contents': 1, 'final': 1, 'till\r\nmidnight': 1, 'last': 6, 'day': 11, 'such': 24, 'announcement.\r\nthe': 1, 'date': 4, 'at\r\nmidnight,': 1, 'central': 1, 'time,': 10, 'stated': 1, 'month.': 2, 'a\r\npreliminary': 1, 'version': 1, 'often': 7, 'posted': 1, 'suggestion,': 1, 'comment\r\nand': 1, 'editing': 1, 'those': 22, 'who': 29, 'wish': 6, 'so.': 2, 'have': 19, 'an\r\nup': 1, '[xxxxx10x.xxx]': 1, 'please': 11, 'check': 2, 'sizes\r\nin': 1, 'week': 1, 'ftp': 3, 'program': 2, 'has\r\na': 1, 'bug': 1, 'it': 131, 'that': 156, 'scrambles': 1, '[tried': 1, 'fix': 1, 'failed]': 1, 'a\r\nlook': 1, 'size': 1, 'will': 68, 'do,': 2, 'but': 88, 'try': 2, 'a\r\nnew': 1, 'copy': 7, 'has': 3, 'least': 4, 'byte': 1, 'more': 32, 'less.\r\n\r\n\r\ninformation': 1, 'about': 12, '(one': 1, 'page)\r\n\r\nwe': 1, 'produce': 2, 'two': 9, 'million': 3, 'dollars': 2, 'each': 11, 'hour': 2, 'work.': 1, 'the\r\ntime': 1, 'takes': 5, 'us,': 2, 'rather': 5, 'conservative': 1, 'estimate,': 1, 'fifty': 1, 'hours\r\nto': 1, 'selected,': 1, 'entered,': 1, 'proofread,': 1, 'edited,': 1, 'copyright\r\nsearched': 1, 'analyzed,': 1, 'letters': 3, 'written,': 1, 'etc.': 2, 'this\r\nprojected': 1, 'audience': 1, 'hundred': 2, 'if': ...

# %%
word_count_list = [(key, value) for key, value in word_count_dictionary.items()]
word_count_list
# Out:
# [('\ufeff\r\n\r\n***the', 1),
#  ('project', 25),
#  ("gutenberg's", 4),
#  ('etext', 20),
#  ('of', 397),
#  ("shakespeare's", 6),
#  ('first', 18),
#  ('folio***\r\n********************the', 2),
#  ('tragedie', 6),
#  ('macbeth*********************\r\n\r\n\r\n\r\n*******************************************************************\r\nthis',
#   1),
#  ('ebook', 1),
#  ('was', 39),
#  ('one', 29),
#  ('early', 1),
#  ('files', 1),
#  ('produced', 1),
#  ('at', 50),
#  ('a\r\ntime', 2),
#  ('when', 28),
#  ('proofing', 2),
#  ('methods', 1),
#  ('and', 426),
#  ('tools', 1),
#  ('were', 34),
#  ('not', 145),
#  ('well', 11),
#  ('developed.', 1),
#  ('there\r\nis', 1),
#  ('an', 28),
#  ('improved', 1),
#  ('edition', 3),
#  ('this', 117),
#  ('title', 2),
#  ('which', 45),
#  ('may', 40),
#  ('be', 137),
#  ('viewed', 1),
#  ('as', 71),
#  ('ebook\r\n(#1533)', 1),
#  ('https://www.gutenberg.org/ebooks/1533\r\n*******************************************************************\r\n\r\n\r\n\r\nthis',
#   1),
#  ('is', 187),
#  ('our', 118),
#  ('3rd', 1),
#  ('most', 26),
#  ('these', 31),
#  ('plays.', 1),
#  ('', 1327),
#  ('see', 29),
#  ('the', 639),
#  ('index.\r\n\r\n\r\ncopyright', 1),
#  ('laws', 2),
#  ('are', 66),
#  ('changing', 1),
#  ('all', 67),
#  ('over', 2),
#  ('world,', 1),
#  ('sure', 3),
#  ('to', 373),
#  ('check\r\nthe', 1),
#  ('copyright', 5),
#  ('for', 104),
#  ('your', 127),
#  ('country', 3),
#  ('before', 14),
#  ('posting', 1),
#  ('files!!\r\n\r\nplease', 1),
#  ('take', 19),
#  ('a', 254),
#  ('look', 2),
#  ('important', 1),
#  ('information', 4),
#  ('in', 185),
#  ('header.\r\nwe', 1),
#  ('encourage', 1),
#  ('you', 200),
#  ('keep', 2),
#  ('file', 4),
#  ('on', 55),
#  ('own', 1),
#  ('disk,', 1),
#  ('keeping', 1),
#  ('an\r\nelectronic', 1),
#  ('path', 1),
#  ('open', 1),
#  ('next', 3),
#  ('readers.', 2),
#  ('do', 37),
#  ('remove', 1),
#  ('this.\r\n\r\n\r\n**welcome', 1),
#  ('world', 3),
#  ('free', 5),
#  ('plain', 3),
#  ('vanilla', 1),
#  ('electronic', 1),
#  ('texts**\r\n\r\n**etexts', 1),
#  ('readable', 1),
#  ('by', 54),
#  ('both', 10),
#  ('humans', 1),
#  ('computers,', 1),
#  ('since', 6),
#  ('1971**\r\n\r\n*these', 1),
#  ('etexts', 8),
#  ('prepared', 3),
#  ('hundreds', 1),
#  ('volunteers', 1),
#  ('donations*\r\n\r\ninformation', 1),
#  ('contacting', 1),
#  ('gutenberg', 12),
#  ('get', 15),
#  ('etexts,', 5),
#  ('and\r\nfurther', 1),
#  ('included', 1),
#  ('below.', 1),
#  ('we', 79),
#  ('need', 6),
#  ('donations.\r\n\r\n\r\nthe', 1),
#  ('macbeth\r\n\r\nby', 1),
#  ('william', 1),
#  ('shakespeare\r\n\r\njuly,', 1),
#  ('2000', 1),
#  ('[etext', 1),
#  ('#2264]\r\n\r\n\r\n***the', 1),
#  ('macbeth*********************\r\n\r\n*****this', 1),
#  ('should', 42),
#  ('named', 1),
#  ('2264.txt', 1),
#  ('or', 62),
#  ('2264.zip******\r\n\r\nproject', 1),
#  ('usually', 2),
#  ('created', 1),
#  ('from', 58),
#  ('multiple', 1),
#  ('editions,\r\nall', 1),
#  ('public', 5),
#  ('domain', 4),
#  ('united', 3),
#  ('states,', 1),
#  ('unless', 2),
#  ('a\r\ncopyright', 1),
#  ('notice', 2),
#  ('included.', 1),
#  ('therefore,', 1),
#  ('any\r\nof', 1),
#  ('books', 2),
#  ('compliance', 1),
#  ('with', 140),
#  ('any', 21),
#  ('particular', 1),
#  ('paper', 1),
#  ('edition.\r\n\r\n\r\nwe', 1),
#  ('now', 25),
#  ('trying', 1),
#  ('release', 4),
#  ('month', 2),
#  ('advance\r\nof', 1),
#  ('official', 2),
#  ('dates,', 1),
#  ('leaving', 1),
#  ('time', 16),
#  ('better', 9),
#  ('editing.\r\n\r\nplease', 1),
#  ('note:', 1),
#  ('neither', 2),
#  ('list', 2),
#  ('nor', 23),
#  ('its', 3),
#  ('contents', 1),
#  ('final', 1),
#  ('till\r\nmidnight', 1),
#  ('last', 6),
#  ('day', 11),
#  ('such', 24),
#  ('announcement.\r\nthe', 1),
#  ('date', 4),
#  ('at\r\nmidnight,', 1),
#  ('central', 1),
#  ('time,', 10),
#  ('stated', 1),
#  ('month.', 2),
#  ('a\r\npreliminary', 1),
#  ('version', 1),
#  ('often', 7),
#  ('posted', 1),
#  ('suggestion,', 1),
#  ('comment\r\nand', 1),
#  ('editing', 1),
#  ('those', 22),
#  ('who', 29),
#  ('wish', 6),
#  ('so.', 2),
#  ('have', 19),
#  ('an\r\nup', 1),
#  ('[xxxxx10x.xxx]', 1),
#  ('please', 11),
#  ('check', 2),
#  ('sizes\r\nin', 1),
#  ('week', 1),
#  ('ftp', 3),
#  ('program', 2),
#  ('has\r\na', 1),
#  ('bug', 1),
#  ('it', 131),
#  ('that', 156),
#  ('scrambles', 1),
#  ('[tried', 1),
#  ('fix', 1),
#  ('failed]', 1),
#  ('a\r\nlook', 1),
#  ('size', 1),
#  ('will', 68),
#  ('do,', 2),
#  ('but', 88),
#  ('try', 2),
#  ('a\r\nnew', 1),
#  ('copy', 7),
#  ('has', 3),
#  ('least', 4),
#  ('byte', 1),
#  ('more', 32),
#  ('less.\r\n\r\n\r\ninformation', 1),
#  ('about', 12),
#  ('(one', 1),
#  ('page)\r\n\r\nwe', 1),
#  ('produce', 2),
#  ('two', 9),
#  ('million', 3),
#  ('dollars', 2),
#  ('each', 11),
#  ('hour', 2),
#  ('work.', 1),
#  ('the\r\ntime', 1),
#  ('takes', 5),
#  ('us,', 2),
#  ('rather', 5),
#  ('conservative', 1),
#  ('estimate,', 1),
#  ('fifty', 1),
#  ('hours\r\nto', 1),
#  ('selected,', 1),
#  ('entered,', 1),
#  ('proofread,', 1),
#  ('edited,', 1),
#  ('copyright\r\nsearched', 1),
#  ('analyzed,', 1),
#  ('letters', 3),
#  ('written,', 1),
#  ('etc.', 2),
#  ('this\r\nprojected', 1),
#  ('audience', 1),
#  ('hundred', 2),
#  ('if', 49),
#  ('value\r\nper', 1),
#  ('text', 2),
#  ('nominally', 1),
#  ('estimated', 1),
#  ('dollar', 1),
#  ('then', 40),
#  ('$2\r\nmillion', 1),
#  ('per', 2),
#  ('year', 1),
#  ('thirty-six', 1),
#  ('text\r\nfiles', 1),
#  ('month,', 1),
#  ('432', 1),
#  ('1999', 1),
#  ('total', 1),
#  ('2000+\r\nif', 1),
#  ('reach', 3),
#  ('just', 2),
#  ('10%', 1),
#  ('computerized', 1),
#  ('population,', 1),
#  ('the\r\ntotal', 1),
#  ('200', 1),
#  ('billion', 1),
#  ('given', 1),
#  ('away', 7),
#  ('year.\r\n\r\nthe', 1),
#  ('goal', 2),
#  ('give', 5),
#  ('trillion', 1),
#  ('etext\r\nfiles', 1),
#  ('december', 1),
#  ('31,', 1),
#  ('2001.', 1),
#  ('[10,000', 1),
#  ('x', 1),
#  ('100,000,000', 1),
#  ('=', 2),
#  ('1', 12),
#  ('trillion]\r\nthis', 1),
#  ('ten', 5),
#  ('thousand', 4),
#  ('titles', 1),
#  ('readers,\r\nwhich', 1),
#  ('only', 5),
#  ('~5%', 1),
#  ('present', 5),
#  ('number', 2),
#  ('computer', 2),
#  ('users.\r\n\r\nat', 1),
#  ('revised', 1),
#  ('rates', 1),
#  ('production,', 1),
#  ('one-third\r\nof', 1),
#  ('end', 2),
#  ('2001,', 1),
#  ('3,333', 1),
#  ('we\r\nmanage', 1),
#  ('some', 19),
#  ('real', 1),
#  ('funding;', 1),
#  ('currently', 1),
#  ('funding', 1),
#  ('mostly\r\nfrom', 1),
#  ('michael', 1),
#  ("hart's", 1),
#  ('salary', 2),
#  ('carnegie-mellon', 2),
#  ('university,', 1),
#  ('an\r\nassortment', 2),
#  ('sporadic', 1),
#  ('gifts;', 1),
#  ('good', 42),
#  ('few\r\nmore', 1),
#  ('years,', 1),
#  ('so', 66),
#  ('looking', 1),
#  ('something', 3),
#  ('replace', 1),
#  ('it,', 15),
#  ("we\r\ndon't", 1),
#  ('want', 5),
#  ('dependent', 1),
#  ('person.\r\n\r\nwe', 1),
#  ('donations', 2),
#  ('than', 7),
#  ('ever!\r\n\r\n\r\nall', 1),
#  ('made', 14),
#  ('"project', 5),
#  ('gutenberg/cmu":', 1),
#  ('are\r\ntax', 1),
#  ('deductible', 1),
#  ('extent', 1),
#  ('allowable', 1),
#  ('law.', 1),
#  ('(cmu', 1),
#  ('carnegie-\r\nmellon', 1),
#  ('university).\r\n\r\nfor', 1),
#  ('other', 20),
#  ('matters,', 2),
#  ('mail', 2),
#  ('to:\r\n\r\nproject', 1),
#  ('gutenberg\r\np.', 1),
#  ('o.', 1),
#  ('box', 1),
#  ('2782\r\nchampaign,', 1),
#  ('il', 1),
#  ('61825\r\n\r\nwhen', 1),
#  ('email', 4),
#  ('fails.', 1),
#  ('.', 17),
#  ('.try', 1),
#  ('executive', 1),
#  ('director:\r\nmichael', 1),
#  ('s.', 3),
#  ('hart', 3),
#  ('<hart@pobox.com>\r\nhart@pobox.com', 1),
#  ('forwards', 1),
#  ('hart@prairienet.org', 1),
#  ('archive.org\r\nif', 1),
#  ('bounces', 2),
#  ('archive.org,', 1),
#  ('i', 261),
#  ('still', 11),
#  ('if\r\nit', 1),
#  ('prairienet.org,', 1),
#  ('resend', 1),
#  ('later', 1),
#  ('on.', 1),
#  ('.\r\n\r\nwe', 1),
#  ('would', 34),
#  ('prefer', 1),
#  ('send', 5),
#  ('email.\r\n\r\n******\r\n\r\nto', 1),
#  ('access', 1),
#  ('use', 4),
#  ('web', 1),
#  ('browser\r\nto', 1),
#  ('view', 1),
#  ('http://promo.net/pg.', 1),
#  ('site', 1),
#  ('lists', 1),
#  ('by\r\nauthor', 1),
#  ('title,', 2),
#  ('includes', 1),
#  ('how\r\nto', 1),
#  ('involved', 1),
#  ('gutenberg.', 1),
#  ('could', 13),
#  ('also\r\ndownload', 1),
#  ('past', 1),
#  ('newsletters,', 1),
#  ('subscribe', 1),
#  ('here.', 1),
#  ('this\r\nis', 1),
#  ('major', 1),
#  ('sites,', 1),
#  ('hart@pobox.com,\r\nfor', 1),
#  ('complete', 1),
#  ('various', 3),
#  ('sites.\r\n\r\nto', 1),
#  ('go', 11),
#  ('directly', 2),
#  ('collections,', 1),
#  ('any\r\nweb', 1),
#  ('browser', 1),
#  ('visit', 1),
#  ('mirror', 1),
#  ('(mirror\r\nsites', 1),
#  ('available', 2),
#  ('7', 1),
#  ('continents;', 1),
#  ('mirrors', 1),
#  ('listed\r\nat', 1),
#  ('http://promo.net/pg).\r\n\r\nmac', 1),
#  ('users,', 1),
#  ('point', 3),
#  ('click,', 1),
#  ('typing', 1),
#  ('works', 1),
#  ('better.\r\n\r\nexample', 1),
#  ('session:\r\n\r\nftp', 1),
#  ('sunsite.unc.edu\r\nlogin:', 1),
#  ('anonymous\r\npassword:', 1),
#  ('your@login\r\ncd', 1),
#  ('pub/docs/books/gutenberg\r\ncd', 1),
#  ('etext90', 1),
#  ('through', 8),
#  ('etext99\r\ndir', 1),
#  ('[to', 4),
#  ('files]\r\nget', 2),
#  ('mget', 1),
#  ('files.', 1),
#  ('.set', 1),
#  ('bin', 2),
#  ('zip', 1),
#  ('gutindex.??', 1),
#  ("year's", 1),
#  ('listing', 2),
#  ('books,', 1),
#  ('e.g.,', 1),
#  ('gutindex.99]\r\nget', 1),
#  ('gutindex.all', 1),
#  ('books]\r\n\r\n***\r\n\r\n**information', 1),
#  ('legal', 3),
#  ('advisor**\r\n\r\n(three', 1),
#  ('pages)\r\n\r\n\r\n***start**the', 1),
#  ('small', 3),
#  ('print!**for', 1),
#  ('etexts**start***\r\nwhy', 1),
#  ('"small', 5),
#  ('print!"', 6),
#  ('statement', 1),
#  ('here?', 2),
#  ('know:', 1),
#  ('lawyers.\r\nthey', 1),
#  ('tell', 8),
#  ('us', 2),
#  ('might', 3),
#  ('sue', 1),
#  ('there', 21),
#  ('wrong', 2),
#  ('with\r\nyour', 1),
#  ('etext,', 5),
#  ('even', 5),
#  ('got', 3),
#  ('from\r\nsomeone', 1),
#  ("what's", 12),
#  ('our\r\nfault.', 1),
#  ('so,', 5),
#  ('among', 5),
#  ('things,', 2),
#  ('statement\r\ndisclaims', 1),
#  ('liability', 1),
#  ('you.', 3),
#  ('also', 3),
#  ('tells', 1),
#  ('how\r\nyou', 1),
#  ('can', 26),
#  ('distribute', 4),
#  ('copies', 5),
#  ('to.\r\n\r\n*before!*', 1),
#  ('read', 5),
#  ('etext\r\nby', 1),
#  ('using', 2),
#  ('reading', 2),
#  ('part', 2),
#  ('gutenberg-tm\r\netext,', 1),
#  ('indicate', 2),
#  ('understand,', 1),
#  ('agree', 2),
#  ('accept\r\nthis', 1),
#  ('statement.', 2),
#  ('not,', 8),
#  ('receive\r\na', 1),
#  ('refund', 3),
#  ('money', 4),
#  ('(if', 2),
#  ('any)', 1),
#  ('paid', 5),
#  ('by\r\nsending', 1),
#  ('request', 3),
#  ('within', 9),
#  ('30', 2),
#  ('days', 3),
#  ('receiving', 1),
#  ('person\r\nyou', 1),
#  ('from.', 2),
#  ('received', 4),
#  ('physical\r\nmedium', 1),
#  ('(such', 1),
#  ('disk),', 1),
#  ('must', 34),
#  ('return', 2),
#  ('request.\r\n\r\nabout', 1),
#  ('gutenberg-tm', 3),
#  ('etexts\r\nthis', 1),
#  ('like', 33),
#  ('gutenberg-\r\ntm', 1),
#  ('"public', 1),
#  ('domain"', 1),
#  ('work', 1),
#  ('distributed', 1),
#  ('professor\r\nmichael', 1),
#  ('association', 1),
#  ('at\r\ncarnegie-mellon', 1),
#  ('university', 1),
#  ('(the', 1),
#  ('"project").', 1),
#  ('other\r\nthings,', 2),
#  ('means', 1),
#  ('no', 62),
#  ('owns', 1),
#  ('states', 3),
#  ('copyright\r\non', 1),
#  ('work,', 2),
#  ('(and', 2),
#  ('you!)', 1),
#  ('and\r\ndistribute', 1),
#  ('without', 10),
#  ('permission', 1),
#  ('and\r\nwithout', 1),
#  ('paying', 1),
#  ('royalties.', 1),
#  ('special', 1),
#  ('rules,', 1),
#  ('set', 8),
#  ('forth\r\nbelow,', 1),
#  ('apply', 3),
#  ('etext\r\nunder', 1),
#  ("project's", 2),
#  ('gutenberg"', 1),
#  ('trademark.\r\n\r\nto', 1),
#  ('create', 2),
#  ('expends', 1),
#  ('considerable\r\nefforts', 1),
#  ('identify,', 1),
#  ('transcribe', 1),
#  ('proofread', 1),
#  ('domain\r\nworks.', 1),
#  ('despite', 1),
#  ('efforts,', 1),
#  ('any\r\nmedium', 1),
#  ('they', 67),
#  ('contain', 2),
#  ('"defects".', 1),
#  ('defects', 1),
#  ('form', 4),
#  ('incomplete,', 1),
#  ('inaccurate', 1),
#  ('or\r\ncorrupt', 1),
#  ('data,', 1),
#  ('transcription', 1),
#  ('errors,', 3),
#  ('other\r\nintellectual', 1),
#  ('property', 1),
#  ('infringement,', 1),
#  ('defective', 1),
#  ('damaged\r\ndisk', 1),
#  ('medium,', 2),
#  ('virus,', 1),
#  ('computer\r\ncodes', 1),
#  ('damage', 1),
#  ('cannot', 18),
#  ('equipment.\r\n\r\nlimited', 1),
#  ('warranty;', 1),
#  ('disclaimer', 1),
#  ('damages\r\nbut', 1),
#  ('"right', 1),
#  ('replacement', 2),
#  ('refund"', 1),
#  ('described', 1),
#  ('below,\r\n[1]', 1),
#  ('party', 1),
#  ('receive', 2),
#  ('this\r\netext', 1),
#  ('etext)', 1),
#  ('disclaims', 1),
#  ('all\r\nliability', 1),
#  ('damages,', 3),
#  ('costs', 1),
#  ('expenses,', 1),
#  ('including\r\nlegal', 1),
#  ('fees,', 2),
#  ('[2]', 2),
#  ('remedies', 1),
#  ('negligence', 1),
#  ('or\r\nunder', 1),
#  ('strict', 1),
#  ('liability,', 2),
#  ('breach', 2),
#  ('warranty', 1),
#  ('contract,\r\nincluding', 1),
#  ('limited', 1),
#  ('indirect,', 1),
#  ('consequential,', 1),
#  ('punitive\r\nor', 1),
#  ('incidental', 1),
#  ('the\r\npossibility', 1),
#  ('damages.\r\n\r\nif', 1),
#  ('discover', 1),
#  ('defect', 1),
#  ('90', 1),
#  ('of\r\nreceiving', 1),
#  ('any)\r\nyou', 1),
#  ('sending', 1),
#  ('explanatory', 1),
#  ('note', 3),
#  ('that\r\ntime', 1),
#  ('person', 4),
#  ('it\r\non', 1),
#  ('physical', 1),
#  ('note,', 1),
#  ('and\r\nsuch', 1),
#  ('choose', 1),
#  ('alternatively', 2),
#  ('replacement\r\ncopy.', 1),
#  ('electronically,', 2),
#  ('may\r\nchoose', 1),
#  ('second', 5),
#  ('opportunity', 1),
#  ('to\r\nreceive', 1),
#  ('electronically.\r\n\r\nthis', 1),
#  ('otherwise', 1),
#  ('provided', 1),
#  ('"as-is".', 1),
#  ('other\r\nwarranties', 1),
#  ('kind,', 1),
#  ('express', 1),
#  ('implied,', 1),
#  ('as\r\nto', 1),
#  ('medium', 2),
#  ('on,', 1),
#  ('including', 3),
#  ('not\r\nlimited', 1),
#  ('warranties', 2),
#  ('merchantability', 1),
#  ('fitness', 1),
#  ('a\r\nparticular', 1),
#  ('purpose.\r\n\r\nsome', 1),
#  ('allow', 1),
#  ('disclaimers', 2),
#  ('implied', 1),
#  ('or\r\nthe', 1),
#  ('exclusion', 1),
#  ('limitation', 1),
#  ('consequential', 1),
#  ('the\r\nabove', 1),
#  ('exclusions', 1),
#  ('you,', 12),
#  ('you\r\nmay', 1),
#  ('rights.\r\n\r\nindemnity\r\nyou', 1),
#  ('indemnify', 1),
#  ('hold', 7),
#  ('project,', 1),
#  ('directors,\r\nofficers,', 1),
#  ('members', 1),
#  ('agents', 2),
#  ('harmless', 1),
#  ('cost\r\nand', 1),
#  ('expense,', 2),
#  ('arise', 1),
#  ('or\r\nindirectly', 1),
#  ('following', 2),
#  ('cause:\r\n[1]', 1),
#  ('distribution', 1),
#  ('alteration,', 1),
#  ('modification,\r\nor', 1),
#  ('addition', 2),
#  ('[3]', 1),
#  ('defect.\r\n\r\ndistribution', 1),
#  ('under', 1),
#  ('gutenberg-tm"\r\nyou', 1),
#  ('by\r\ndisk,', 1),
#  ('book', 1),
#  ('either', 2),
#  ('delete', 2),
#  ('this\r\n"small', 1),
#  ('references', 1),
#  ('gutenberg,\r\nor:\r\n\r\n[1]', 1),
#  ('exact', 1),
#  ('it.', 5),
#  ('this\r\n', 2),
#  ('requires', 1),
#  ('remove,', 1),
#  ('alter', 2),
#  ('modify', 1),
#  ('the\r\n', 4),
#  ('however,\r\n', 1),
#  ('wish,', 1),
#  ('machine', 1),
#  ('readable\r\n', 1),
#  ('binary,', 1),
#  ('compressed,', 1),
#  ('mark-up,', 1),
#  ('proprietary', 2),
#  ('form,\r\n', 1),
#  ('resulting', 1),
#  ('conversion', 1),
#  ('word', 5),
#  ('pro-\r\n', 1),
#  ('cessing', 1),
#  ('hypertext', 2),
#  ('software,', 2),
#  ('long', 4),
#  ('as\r\n', 1),
#  ('*either*:\r\n\r\n', 1),
#  ('[*]', 3),
#  ('displayed,', 1),
#  ('clearly', 1),
#  ('readable,', 1),
#  ('and\r\n', 1),
#  ('does', 8),
#  ('*not*', 2),
#  ('characters', 4),
#  ('those\r\n', 1),
#  ('intended', 2),
#  ('author', 1),
#  ('although', 1),
#  ('tilde\r\n', 1),
#  ('(~),', 1),
#  ('asterisk', 1),
#  ('(*)', 1),
#  ('underline', 1),
#  ('(_)', 1),
#  ('may\r\n', 1),
#  ('used', 4),
#  ('convey', 1),
#  ('punctuation', 1),
#  ('author,', 1),
#  ('additional', 2),
#  ('to\r\n', 1),
#  ('links;', 1),
#  ('or\r\n\r\n', 2),
#  ('readily', 1),
#  ('converted', 1),
#  ('reader', 1),
#  ('at\r\n', 2),
#  ('expense', 1),
#  ('into', 15),
#  ('ascii,', 1),
#  ('ebcdic', 1),
#  ('equivalent\r\n', 1),
#  ('displays', 1),
#  ('(as', 4),
#  ('is\r\n', 1),
#  ('case,', 1),
#  ('instance,', 1),
#  ('processors);\r\n', 1),
#  ('provide,', 1),
#  ('provide', 1),
#  ('cost,', 1),
#  ('fee', 2),
#  ('original', 1),
#  ('ascii', 2),
#  ('(or', 3),
#  ('ebcdic\r\n', 1),
#  ('equivalent', 2),
#  ('form).\r\n\r\n[2]', 1),
#  ('honor', 6),
#  ('provisions', 1),
#  ('statement.\r\n\r\n[3]', 1),
#  ('pay', 3),
#  ('trademark', 1),
#  ('license', 1),
#  ('20%', 1),
#  ('net', 1),
#  ('profits', 1),
#  ('derive', 2),
#  ('calculated', 1),
#  ('method', 1),
#  ('you\r\n', 2),
#  ('already', 2),
#  ('calculate', 1),
#  ('applicable', 1),
#  ('taxes.', 1),
#  ("don't", 3),
#  ('profits,', 1),
#  ('royalty', 2),
#  ('due.', 1),
#  ('royalties', 1),
#  ('are\r\n', 1),
#  ('payable', 1),
#  ('association/carnegie-mellon\r\n', 1),
#  ('university"', 1),
#  ('60', 1),
#  ('each\r\n', 1),
#  ('prepare', 1),
#  ('legally', 1),
#  ('required', 1),
#  ('prepare)\r\n', 1),
#  ('annual', 1),
#  ('periodic)', 1),
#  ('tax', 1),
#  ('return.\r\n\r\nwhat', 1),
#  ('*want*', 1),
#  ('to?\r\nthe', 1),
#  ('gratefully', 1),
#  ('accepts', 1),
#  ('contributions', 1),
#  ('money,', 1),
#  ('time,\r\nscanning', 1),
#  ('machines,', 1),
#  ('ocr', 1),
#  ('royalty\r\nfree', 1),
#  ('licenses,', 1),
#  ('every', 1),
#  ('sort', 1),
#  ('contribution\r\nyou', 1),
#  ('think', 2),
#  ('of.', 1),
#  ('gutenberg\r\nassociation', 1),
#  ('/', 1),
#  ('university".\r\n\r\n*end*the', 1),
#  ('print!', 1),
#  ('etexts*ver.04.29.93*end*\r\n\r\n\r\n\r\n\r\n\r\nproject', 1),
#  ('macbeth\r\n\r\n\r\n\r\n\r\n\r\nexecutive', 1),
#  ("director's", 1),
#  ('notes:\r\n\r\nin', 1),
#  ('notes', 1),
#  ('below,', 1),
#  ('all\r\nthe', 1),
#  ('spelling', 4),
#  ('errors', 2),
#  ('introduced', 1),
#  ('printers', 2),
#  ('have\r\nbeen', 1),
#  ('corrected,', 1),
#  ('here', 10),
#  ('few', 2),
#  ('lines', 1),
#  ('hamlet,', 1),
#  ('they\r\nare', 1),
#  ('presented', 1),
#  ('herein:\r\n\r\n', 1),
#  ('barnardo.', 1),
#  ("who's", 7),
#  ('there?\r\n', 2),
#  ('fran.', 1),
#  ('nay', 2),
#  ('answer', 4),
#  ('me:', 3),
#  ('stand', 9),
#  ('&', 18),
#  ('vnfold\r\nyour', 1),
#  ('selfe\r\n\r\n', 1),
#  ('bar.', 1),
#  ('liue', 7),
#  ('king\r\n\r\n***\r\n\r\nas', 1),
#  ('understand', 1),
#  ('ran', 2),
#  ('out', 18),
#  ('certain', 1),
#  ('words\r\nor', 1),
#  ('had', 33),
#  ('packed', 2),
#  ('"cliche".', 1),
#  ('.this', 1),
#  ('the\r\noriginal', 1),
#  ('meaning', 1),
#  ('term', 1),
#  ('cliche.', 1),
#  ('.and', 3),
#  ('thus,', 2),
#  ('being', 10),
#  ('unwilling\r\nto', 1),
#  ('unpack', 1),
#  ('cliches,', 1),
#  ('thus', 5),
#  ('substitutions\r\nthat', 1),
#  ('very', 12),
#  ('odd.', 1),
#  ('.such', 1),
#  ('exchanges', 1),
#  ('u', 1),
#  ('v,', 1),
#  ('v', 1),
#  ('u,\r\nabove.', 1),
#  ('wonder', 2),
#  ('why', 20),
#  ('did', 38),
#  ('way,', 2),
#  ('presuming\r\nshakespeare', 1),
#  ('actually', 1),
#  ('write', 2),
#  ('play', 5),
#  ('manner.', 1),
#  ('.\r\n\r\nthe', 1),
#  ('"liue"', 1),
#  ('cliche', 1),
#  ('"v"\'s.', 1),
#  ('.possibly', 1),
#  ('having', 1),
#  ('"vv"', 1),
#  ('in\r\nplace', 1),
#  ('"w"\'s,', 1),
#  ('common', 3),
#  ('practice', 1),
#  ('day,\r\nas', 1),
#  ('print', 1),
#  ('quite', 2),
#  ('expensive,', 1),
#  ("didn't", 1),
#  ('spend\r\nmore', 1),
#  ('wider', 1),
#  ('selection', 1),
#  ('to.\r\n\r\nyou', 1),
#  ('find', 2),
#  ('lot', 1),
#  ('kinds', 1),
#  ('"errors"', 1),
#  ('text,', 1),
#  ('i\r\nhave', 1),
#  ('mentioned', 2),
#  ('times', 4),
#  ('places,', 1),
#  ('many', 11),
#  ('"scholars"', 1),
#  ('an\r\nextreme', 1),
#  ('attachment', 1),
#  ('accorded', 1),
#  ('them', 20),
#  ('a\r\nvery', 1),
#  ('high', 6),
#  ('place', 3),
#  ('"canon"', 1),
#  ('shakespeare.', 1),
#  ('my', 192),
#  ('father', 5),
#  ('him', 46),
#  ('cambridge', 1),
#  ('university\r\nin', 1),
#  ('england', 3),
#  ('several', 2),
#  ('months', 1),
#  ('glass', 1),
#  ('room', 1),
#  ('constructed', 1),
#  ('the\r\npurpose.', 1),
#  ('best', 9),
#  ('knowledge', 2),
#  ('he', 86),
#  ('available\r\n.', 1),
#  ('.in', 1),
#  ('great', 27),
#  ('detail.', 1),
#  ('determined', 1),
#  ('changes,\r\nthat', 1),
#  ('shakespeare', 1),
#  ('likely', 1),
#  ('nearly', 1),
#  ('a\r\nvariety', 1),
#  ('credit', 1),
#  ('for,', 1),
#  ('though', 10),
#  ('in/famous\r\nfor', 1),
#  ('signing', 1),
#  ('his', 130),
#  ('name', 9),
#  ('different', 1),
#  ('spellings.\r\n\r\nso,', 1),
#  ('account', 2),
#  ('comments', 1),
#  ('below\r\nmade', 1),
#  ('volunteer', 1),
#  ('file:', 1),
#  ('errors\r\nthat', 1),
#  ('"not"', 1),
#  ...]

# %%
word_count_list_sorted = sorted(word_count_list, key=lambda tup: tup[1], reverse=True)

top25 = word_count_list_sorted[1:25]
top25
# Out:
# [('the', 639),
#  ('and', 426),
#  ('of', 397),
#  ('to', 373),
#  ('i', 261),
#  ('a', 254),
#  ('you', 200),
#  ('my', 192),
#  ('is', 187),
#  ('in', 185),
#  ('that', 156),
#  ('not', 145),
#  ('with', 140),
#  ('be', 137),
#  ('macb.', 137),
#  ('it', 131),
#  ('his', 130),
#  ('your', 127),
#  ('our', 118),
#  ('this', 117),
#  ('haue', 106),
#  ('for', 104),
#  ('but', 88),
#  ('he', 86)]

# %%
xvalues = [tup[0] for tup in top25]
yvalues = [tup[1] for tup in top25]

plt.figure(figsize=(8, 5))
plt.bar(xvalues, yvalues)
plt.title("Top 25 Words in Macbeth")
plt.xticks(rotation=90)
plt.show()

# %%
# Your code here

# Pseudo-code Outline
# Split the transcript into words
# Create a dictionary
# Iterate through the text of Macbeth
# Update word counts
# Create Bar Graph
# Include descriptive titles and labels

# %% [markdown]
# ## Level Up (Optional)
# This project should take you about an hour and a half to complete. If you're done much more quickly than that and are not behind in the course, feel free to deepen your knowledge by completing any or all of the following tasks until you run out of time:
# * Create a list of top characters by mentions of their names
# * Split the text by which character is talking
# * Create subgraphs of the most common words by character
# * Reduce the string to the text of the play itself. (Remove any initial notes, forward, introduction, appendix, etc.)
# * Come up with some other fun analyses of the text!
#
# ## Summary
# Congratulations! You've got some extra practice combining various data types into useful programming patterns and done an initial analysis of a classic text!
